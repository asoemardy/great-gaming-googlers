# %%
# Getting dependencies
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
import threading

# %%
headers = {
    'client-id': 'py6ylcmszc7x2mv3ssej6cxhe3qaj9',
    'Authorization': 'Bearer qa1qavdau81s0hm14dbnu8t5ty32h4',
}

params = (
    ('query', 'summit1g'),
)

response = requests.get('https://api.twitch.tv/helix/search/channels', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.twitch.tv/helix/search/channels?query=summit1g', headers=headers)

response.content
# Out:
# b'{"data":[{"broadcaster_language":"en","display_name":"summit1g","game_id":"510218","id":"26490481","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/99aa4739-21d6-40af-86ae-4b4d3457fce4-profile_image-300x300.png","title":"among us chillin.  [ @summit1g ]","started_at":""},{"broadcaster_language":"en","display_name":"summit1gqxa","game_id":"32399","id":"502248227","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/28557ffb-9dfe-4ef2-837c-48434d0aa908-profile_image-300x300.png","title":"\xf0\x9f\x8e\x81Summit1g |GIVEAWAY 12000$\xf0\x9f\x8e\x81","started_at":""},{"broadcaster_language":"en","display_name":"summit1giscool","game_id":"0","id":"61757953","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/user-default-pictures-uv/ead5c8b2-a4c9-4724-b1dd-9f00b46cbd3d-profile_image-300x300.png","title":"spellbreak","started_at":""},{"broadcaster_language":"pt","display_name":"summit1govq","game_id":"32399","id":"502247452","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/3bce3461-be14-4075-89a5-79b72ab06854-profile_image-300x300.png","title":"\xf0\x9f\x94\xb4Summit1g |GIVEAWAY 222 KNIFE\xf0\x9f\x8e\x81","started_at":""},{"broadcaster_language":"en","display_name":"summit1gin","game_id":"32399","id":"489976206","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/f5f21ab6-432c-44a6-aaee-f5654b71bff8-profile_image-300x300.png","title":"\xf0\x9f\x94\xb4Summit1g | 777 KNIFE GIVEAWAY\xf0\x9f\x8e\x81","started_at":""},{"broadcaster_language":"en","display_name":"summit1gcut","game_id":"0","id":"595375462","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/user-default-pictures-uv/cdd517fe-def4-11e9-948e-784f43822e80-profile_image-300x300.png","title":"","started_at":""},{"broadcaster_language":"en","display_name":"summit1gwho","game_id":"0","id":"539324362","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/user-default-pictures-uv/75305d54-c7cc-40d1-bb9c-91fbe85943c7-profile_image-300x300.png","title":"Overwatch qp","started_at":""},{"broadcaster_language":"en","display_name":"summit1ggmr","game_id":"32399","id":"502247453","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/a3ad52aa-fad2-4d6d-ad92-d4a8a69d4c92-profile_image-300x300.png","title":"Summit1g |GIVEAWAY 12000$","started_at":""},{"broadcaster_language":"en","display_name":"summit1gudi","game_id":"32399","id":"502251134","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/3b0ce049-acf8-4c24-a401-749adc901508-profile_image-300x300.png","title":"Summit1g | Free skins for everyone!","started_at":""},{"broadcaster_language":"en","display_name":"summit1gqk","game_id":"32399","id":"489975875","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/51015954-b05b-40b0-b0b7-38f3fdcdceb1-profile_image-300x300.png","title":"Summit1g | Free skins for everyone!","started_at":""},{"broadcaster_language":"en","display_name":"summit1gea","game_id":"32399","id":"484709527","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/32552410-d32e-4ae0-aa1e-55766f7aa2c2-profile_image-300x300.png","title":"Summit1g | Chrimas Giveaway!","started_at":""},{"broadcaster_language":"en","display_name":"summit1gws","game_id":"32399","id":"484693919","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/1718acba-11ad-49bb-ae53-c1cc7e98cb41-profile_image-300x300.png","title":"Summit1g | Chrimas Giveaway!","started_at":""},{"broadcaster_language":"en","display_name":"summit1g_ab","game_id":"32399","id":"479726333","is_live":false,"tag_ids":[],"thumbnail_url":"https://static-cdn.jtvnw.net/jtv_user_pictures/d2286f0b-6e6b-43e4-b168-a45437290fee-profile_image-300x300.png","title":"Summit1 ...

# %%
response.json()
# Out:
# {'data': [{'broadcaster_language': 'en',
#    'display_name': 'summit1g',
#    'game_id': '510218',
#    'id': '26490481',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/99aa4739-21d6-40af-86ae-4b4d3457fce4-profile_image-300x300.png',
#    'title': 'among us chillin.  [ @summit1g ]',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gqxa',
#    'game_id': '32399',
#    'id': '502248227',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/28557ffb-9dfe-4ef2-837c-48434d0aa908-profile_image-300x300.png',
#    'title': '🎁Summit1g |GIVEAWAY 12000$🎁',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1giscool',
#    'game_id': '0',
#    'id': '61757953',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/ead5c8b2-a4c9-4724-b1dd-9f00b46cbd3d-profile_image-300x300.png',
#    'title': 'spellbreak',
#    'started_at': ''},
#   {'broadcaster_language': 'pt',
#    'display_name': 'summit1govq',
#    'game_id': '32399',
#    'id': '502247452',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/3bce3461-be14-4075-89a5-79b72ab06854-profile_image-300x300.png',
#    'title': '🔴Summit1g |GIVEAWAY 222 KNIFE🎁',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gin',
#    'game_id': '32399',
#    'id': '489976206',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/f5f21ab6-432c-44a6-aaee-f5654b71bff8-profile_image-300x300.png',
#    'title': '🔴Summit1g | 777 KNIFE GIVEAWAY🎁',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gcut',
#    'game_id': '0',
#    'id': '595375462',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/cdd517fe-def4-11e9-948e-784f43822e80-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gwho',
#    'game_id': '0',
#    'id': '539324362',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/75305d54-c7cc-40d1-bb9c-91fbe85943c7-profile_image-300x300.png',
#    'title': 'Overwatch qp',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1ggmr',
#    'game_id': '32399',
#    'id': '502247453',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/a3ad52aa-fad2-4d6d-ad92-d4a8a69d4c92-profile_image-300x300.png',
#    'title': 'Summit1g |GIVEAWAY 12000$',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gudi',
#    'game_id': '32399',
#    'id': '502251134',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/3b0ce049-acf8-4c24-a401-749adc901508-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gqk',
#    'game_id': '32399',
#    'id': '489975875',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/51015954-b05b-40b0-b0b7-38f3fdcdceb1-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gea',
#    'game_id': '32399',
#    'id': '484709527',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/32552410-d32e-4ae0-aa1e-55766f7aa2c2-profile_image-300x300.png',
#    'title': 'Summit1g | Chrimas Giveaway!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gws',
#    'game_id': '32399',
#    'id': '484693919',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/1718acba-11ad-49bb-ae53-c1cc7e98cb41-profile_image-300x300.png',
#    'title': 'Summit1g | Chrimas Giveaway!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1g_ab',
#    'game_id': '32399',
#    'id': '479726333',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/d2286f0b-6e6b-43e4-b168-a45437290fee-profile_image-300x300.png',
#    'title': 'Summit1g | Chrimas Giveaway!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1g_aa',
#    'game_id': '32399',
#    'id': '479715935',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/3a42b093-8a7c-4c16-b154-f1b4f1431f33-profile_image-300x300.png',
#    'title': 'Summit1g | Chrimas Giveaway!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1g_rs',
#    'game_id': '32399',
#    'id': '479481807',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/7af057ed-9a33-45c2-a5dd-1d4450639dbc-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1g_gq',
#    'game_id': '32399',
#    'id': '479109700',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/7fd7f8a1-be72-4572-a333-1f5fa7ebd6a3-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1g_ggg',
#    'game_id': '32399',
#    'id': '479106069',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/7a22e99e-ef83-4dc7-b613-0690afed041e-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gyd',
#    'game_id': '32399',
#    'id': '278444011',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/6b112d7f-9232-4442-83b8-71c8fc228c9b-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gnc',
#    'game_id': '32399',
#    'id': '278443741',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/5fb72ea3-39b1-4060-ab0e-0383bc4b0011-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'summit1gvrh',
#    'game_id': '32399',
#    'id': '502250388',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/26e788d1-f2f3-4b7c-8412-3f91b5096033-profile_image-300x300.png',
#    'title': 'Summit1g | Free skins for everyone!',
#    'started_at': ''}],
#  'pagination': {'cursor': 'MjA='}}
