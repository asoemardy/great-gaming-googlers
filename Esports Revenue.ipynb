# %%
# Getting dependencies
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
import threading

# %%
# Pulling top 50 data from csv file in Data
df_esports = pd.read_csv('Data/GeneralEsportData2.csv')
df_esports.head()
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      190075.61
# 1      Age of Empires II         1999  Strategy     1480089.01
# 2     Age of Empires III         2005  Strategy       66463.85
# 3  Age of Empires Online         2011  Strategy        2668.00
# 4       Age of Mythology         2002  Strategy       52360.00
#
#    OnlineEarnings  TotalPlayers  TotalTournaments
# 0        33235.72           246                95
# 1       862909.14           827               549
# 2        24963.85            86                72
# 3         2668.00            16                 7
# 4          360.00            22                 6

# %%
df_esports = df_esports.sort_values(by = 'TotalEarnings', ascending = False)
df_esports.head(50)
# Out:
#                                      Game  ReleaseDate  \
# 155                                Dota 2         2013
# 77       Counter-Strike: Global Offensive         2012
# 479                              Fortnite         2017
# 160                     League of Legends         2009
# 28                           StarCraft II         2010
# 483         PLAYERUNKNOWN’S BATTLEGROUNDS         2017
# 456                           Hearthstone         2014
# 110                             Overwatch         2016
# 158                   Heroes of the Storm         2015
# 149                        Arena of Valor         2015
# 74                         Counter-Strike         2000
# 121                     Rainbow Six Siege         2015
# 449                         Rocket League         2015
# 166                                 SMITE         2014
# 29                   StarCraft: Brood War         1998
# 64              Call of Duty: Black Ops 4         2018
# ...

# %%
df_esports.to_csv('Data/Esportsrevenue.csv', index = False)
