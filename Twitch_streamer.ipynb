# %%
# Getting dependencies
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
import threading

# %%
headers = {
    'client-id': 'py6ylcmszc7x2mv3ssej6cxhe3qaj9',
    'Authorization': 'Bearer qa1qavdau81s0hm14dbnu8t5ty32h4',
}

params = (
    ('query', 'loltyler1'),
)

response = requests.get('https://api.twitch.tv/helix/search/channels', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.twitch.tv/helix/search/channels?query=summit1g', headers=headers)

response.json()
# Out:
# {'data': [{'broadcaster_language': 'en',
#    'display_name': 'loltyler1',
#    'game_id': '21779',
#    'id': '51496027',
#    'is_live': True,
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/f3591dbe4ee3d94b-profile_image-300x300.png',
#    'title': 'T1 T1 !  HE DO BE DIFFERENT THIS WAY !! AHAHA !',
#    'started_at': '2020-10-19T23:40:24Z'},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1si',
#    'game_id': '0',
#    'id': '589858039',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/a46325f6-f0dd-4ee3-8954-85057f027454-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'sv',
#    'display_name': 'loltyler1_com',
#    'game_id': '21779',
#    'id': '153274810',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/a785b0d0-c8ef-49f7-8ac0-2556e3431418-profile_image-300x300.png',
#    'title': 'MASTER PROMOS ',
#    'started_at': ''},
#   {'broadcaster_language': 'de',
#    'display_name': 'loltyler1_play_with_greek',
#    'game_id': '21779',
#    'id': '78928335',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/672d3cfc-1d27-4ab5-a709-c5b2eec600d9-profile_image-300x300.png',
#    'title': 'clashed your mum last night',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1mems',
#    'game_id': '23020',
#    'id': '574551074',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/cdd517fe-def4-11e9-948e-784f43822e80-profile_image-300x300.png',
#    'title': 'playing JToH',
#    'started_at': ''},
#   {'broadcaster_language': '',
#    'display_name': 'loltyler1playtop',
#    'game_id': '0',
#    'id': '563498132',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/294c98b5-e34d-42cd-a8f0-140b72fba9b0-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1sf',
#    'game_id': '0',
#    'id': '558349462',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/780407a2-953e-4f53-8f5c-384b72514fc6-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1lol0',
#    'game_id': '0',
#    'id': '499853456',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/28377a40-c4ff-407d-b986-ce8d37b448a7-profile_image-300x300.png',
#    'title': 'GETTING A GLIZZY FIT\nName is yunnglean08',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1poppin',
#    'game_id': '0',
#    'id': '490594030',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/41780b5a-def8-11e9-94d9-784f43822e80-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1dotcomdisoalpha',
#    'game_id': '0',
#    'id': '561884416',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/294c98b5-e34d-42cd-a8f0-140b72fba9b0-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1pl',
#    'game_id': '0',
#    'id': '597843580',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/58be6e5b-cf85-466d-b472-4919ca1055e7-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': '',
#    'display_name': 'loltyler123456',
#    'game_id': '0',
#    'id': '596757838',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/215b7342-def9-11e9-9a66-784f43822e80-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': '',
#    'display_name': 'loltyler12345w',
#    'game_id': '0',
#    'id': '596755720',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/294c98b5-e34d-42cd-a8f0-140b72fba9b0-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1wa',
#    'game_id': '0',
#    'id': '596361988',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/4ca9093b-79a1-455e-a63f-a024676052fe-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1at',
#    'game_id': '0',
#    'id': '596320834',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/75305d54-c7cc-40d1-bb9c-91fbe85943c7-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1qm',
#    'game_id': '0',
#    'id': '593522126',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/294c98b5-e34d-42cd-a8f0-140b72fba9b0-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1ft',
#    'game_id': '0',
#    'id': '593521420',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/ebb84563-db81-4b9c-8940-64ed33ccfc7b-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'loltyler1jh',
#    'game_id': '0',
#    'id': '593507311',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/ce57700a-def9-11e9-842d-784f43822e80-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': '',
#    'display_name': 'loltyler1mo',
#    'game_id': '0',
#    'id': '593493685',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/75305d54-c7cc-40d1-bb9c-91fbe85943c7-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''},
#   {'broadcaster_language': '',
#    'display_name': 'loltyler1sd',
#    'game_id': '0',
#    'id': '592572745',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/ebb84563-db81-4b9c-8940-64ed33ccfc7b-profile_image-300x300.png',
#    'title': '',
#    'started_at': ''}],
#  'pagination': {'cursor': 'MjA='}}

# %%
headers2 = {
    'Authorization': 'Bearer qa1qavdau81s0hm14dbnu8t5ty32h4',
    'Client-Id': 'py6ylcmszc7x2mv3ssej6cxhe3qaj9',
}

params2 = (
    ('id', '493057'),
)

response2 = requests.get('https://api.twitch.tv/helix/games', headers=headers2, params=params2)

response2.json()
# Out:
# {'data': [{'id': '493057',
#    'name': "PLAYERUNKNOWN'S BATTLEGROUNDS",
#    'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-{width}x{height}.jpg'}]}
