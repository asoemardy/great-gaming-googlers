# %%
# Getting dependencies
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
import threading

# %%
headers = {
    'client-id': 'py6ylcmszc7x2mv3ssej6cxhe3qaj9',
    'Authorization': 'Bearer qa1qavdau81s0hm14dbnu8t5ty32h4',
}

params = (
    ('query', 'pokimane'),
)

response = requests.get('https://api.twitch.tv/helix/search/channels', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.twitch.tv/helix/search/channels?query=summit1g', headers=headers)

response.json()
# Out:
# {'data': [{'broadcaster_language': 'en',
#    'display_name': 'pokimane',
#    'game_id': '509658',
#    'id': '44445592',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/beeafc17-3ebe-4e1d-b250-404f1ea56988-profile_image-300x300.png',
#    'title': 'see ya soon ^_^',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'marcfryd',
#    'game_id': '0',
#    'id': '44710465',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/1beaa109-5919-4147-bf11-2ff17b13fd91-profile_image-300x300.png',
#    'title': '<3',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimaneignoredyourdono',
#    'game_id': '509667',
#    'id': '60981930',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/4a6a7011-c9b6-4df1-b984-2c7fa82d5de7-profile_image-300x300.png',
#    'title': "PokimaneIgnoredYourDono's mobile stream",
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimane__simp',
#    'game_id': '27471',
#    'id': '424190098',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/5b74a67e-e011-455a-8522-c693aa9c3ac2-profile_image-300x300.png',
#    'title': 'POGMAN69',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimaneandmrfresh',
#    'game_id': '0',
#    'id': '491584654',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/38ed5989-60f5-4e23-aa27-52da8230ad24-profile_image-300x300.png',
#    'title': 'ITS MY BDAY! Yaay!',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanewf',
#    'game_id': '459931',
#    'id': '426684265',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/e8e08e7f-aef3-4764-855f-6810fb1e79fb-profile_image-300x300.png',
#    'title': 'Streaming osrs on main for 20- 30 mins ',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanelol',
#    'game_id': '513319',
#    'id': '441866031',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/de130ab0-def7-11e9-b668-784f43822e80-profile_image-300x300.png',
#    'title': 'Its litttttttt',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimane_2point0',
#    'game_id': '33214',
#    'id': '533056566',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/3690353c-ca2b-460c-b197-056814f5641c-profile_image-300x300.png',
#    'title': 'fortnnnnnnnnnnitee',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanessimp',
#    'game_id': '512710',
#    'id': '150057065',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/0d5d9755-8424-4d6f-92fa-2179b7016b3c-profile_image-300x300.png',
#    'title': 'For james',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimaneshot2',
#    'game_id': '33214',
#    'id': '249671675',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/cdd517fe-def4-11e9-948e-784f43822e80-profile_image-300x300.png',
#    'title': 'Fortnite stream',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanetier3',
#    'game_id': '27471',
#    'id': '542721236',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/75305d54-c7cc-40d1-bb9c-91fbe85943c7-profile_image-300x300.png',
#    'title': 'SECRET STREAM',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimane120',
#    'game_id': '33214',
#    'id': '236004359',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/cdd517fe-def4-11e9-948e-784f43822e80-profile_image-300x300.png',
#    'title': "Minty_Fruitcake's Live PS4 Broadcast",
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimane_is_great',
#    'game_id': '33214',
#    'id': '236697129',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/cdd517fe-def4-11e9-948e-784f43822e80-profile_image-300x300.png',
#    'title': 'fortnite',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanefan3621',
#    'game_id': '27471',
#    'id': '455611082',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/f7dc46bc-eb12-41b8-8cba-6f5f4d7853e9-profile_image-300x300.png',
#    'title': 'Pro Minecrafter Plays Hypixel On His 2.5k PC! (EPIC) ',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimane13223',
#    'game_id': '27471',
#    'id': '489897167',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/3248a4c4-ec28-449a-ba0d-a4644e541ef6-profile_image-300x300.png',
#    'title': 'Schlecht sein  #Lost Gohst_Mefix',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanestoez',
#    'game_id': '18846',
#    'id': '74102566',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/93e2b4d0-e768-4a18-9394-968805ec6c0f-profile_image-300x300.png',
#    'title': 'Gmod darkrp Gunshop RP',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanefan689',
#    'game_id': '24193',
#    'id': '536417052',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/22184dd8-6b69-4aef-b791-8a63517b562f-profile_image-300x300.png',
#    'title': 'hes has to spam',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimaneimurbigestfan',
#    'game_id': '26936',
#    'id': '541794406',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/ead5c8b2-a4c9-4724-b1dd-9f00b46cbd3d-profile_image-300x300.png',
#    'title': "pokimaneimurbigestfan's mobile stream",
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimanetwitch',
#    'game_id': '509658',
#    'id': '487590567',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/d2e099c9-9bb4-4583-8e88-a819de3d6310-profile_image-300x300.png',
#    'title': 'Beyblade episode 3 om Ligit and Logic ',
#    'started_at': ''},
#   {'broadcaster_language': 'en',
#    'display_name': 'pokimane_simp123',
#    'game_id': '0',
#    'id': '573544229',
#    'is_live': False,
#    'tag_ids': [],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/45b5ee6b-7071-484c-8e3f-9c34186ceb02-profile_image-300x300.png',
#    'title': 'Siege',
#    'started_at': ''}],
#  'pagination': {'cursor': 'MjA='}}

# %%
headers2 = {
    'Authorization': 'Bearer qa1qavdau81s0hm14dbnu8t5ty32h4',
    'Client-Id': 'py6ylcmszc7x2mv3ssej6cxhe3qaj9',
}

params2 = (
    ('id', '459931'),
)

response2 = requests.get('https://api.twitch.tv/helix/games', headers=headers2, params=params2)

response2.json()
# Out:
# {'data': [{'id': '459931',
#    'name': 'Old School RuneScape',
#    'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Old%20School%20RuneScape-{width}x{height}.jpg'}]}
