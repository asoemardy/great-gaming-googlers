# %%
# Getting dependencies
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
import threading

# %%
df_steam = pd.read_csv('Data/steamdata.csv')
df_steam.head(50)
# Out:
#     appid                                 name release_date  english  \
# 0      10                       Counter-Strike   2000-11-01        1
# 1      20                Team Fortress Classic   1999-04-01        1
# 2      30                        Day of Defeat   2003-05-01        1
# 3      40                   Deathmatch Classic   2001-06-01        1
# 4      50            Half-Life: Opposing Force   1999-11-01        1
# 5      60                             Ricochet   2000-11-01        1
# 6      70                            Half-Life   1998-11-08        1
# 7      80       Counter-Strike: Condition Zero   2004-03-01        1
# 8     130                Half-Life: Blue Shift   2001-06-01        1
# 9     220                          Half-Life 2   2004-11-16        1
# 10    240               Counter-Strike: Source   2004-11-01        1
# 11    280                    Half-Life: Source   2004-06-01        1
# 12    300                Day of Defeat: Source   2010-07-12        1
# ...

# %%
df_steam = df_steam [['name', 'genres' ,  'average_playtime', 'price', 'owners', 'positive_ratings']]
df_steam .head(50)
# Out:
#                                    name  \
# 0                        Counter-Strike
# 1                 Team Fortress Classic
# 2                         Day of Defeat
# 3                    Deathmatch Classic
# 4             Half-Life: Opposing Force
# 5                              Ricochet
# 6                             Half-Life
# 7        Counter-Strike: Condition Zero
# 8                 Half-Life: Blue Shift
# 9                           Half-Life 2
# 10               Counter-Strike: Source
# 11                    Half-Life: Source
# 12                Day of Defeat: Source
# 13              Half-Life 2: Deathmatch
# 14              Half-Life 2: Lost Coast
# 15         Half-Life Deathmatch: Source
# 16             Half-Life 2: Episode One
# 17                               Portal
# 18             Half-Life 2: Episode Two
# 19                      Team Fortress 2
# 20                          Left 4 Dead
# 21                        Left 4 Dead 2
# ...

# %%
df_steam.to_csv('Data/clean_steam_data.csv', index = False)

# %%
df_steam
# Out:
#                              name                  genres  average_playtime  \
# 0                  Counter-Strike                  Action             17612
# 1           Team Fortress Classic                  Action               277
# 2                   Day of Defeat                  Action               187
# 3              Deathmatch Classic                  Action               258
# 4       Half-Life: Opposing Force                  Action               624
# ...                           ...                     ...               ...
# 27070             Room of Pandora  Adventure;Casual;Indie                 0
# 27071                   Cyber Gun  Action;Adventure;Indie                 0
# 27072            Super Star Blast     Action;Casual;Indie                 0
# 27073  New Yankee 7: Deer Hunters  Adventure;Casual;Indie                 0
# 27074                   Rune Lord  Adventure;Casual;Indie                 0
#
#        price             owners  positive_ratings
# ...

# %%
df_steam[df_steam['name']=='Among Us']
# Out:
#            name  genres  average_playtime  price   owners  positive_ratings
# 24798  Among Us  Casual                 0   3.99  0-20000                60
