# %%
# Importing Dependencies
import pandas as pd
import numpy as np

# %%
# Read twitch streamer file into panda dataframe

df_streamer = pd.read_csv("Data/twitchdata-update.csv")

df_streamer
# Out:
#               Channel  Watch time(Minutes)  Stream time(minutes)  \
# 0               xQcOW           6196161750                215250
# 1            summit1g           6091677300                211845
# 2              Gaules           5644590915                515280
# 3            ESL_CSGO           3970318140                517740
# 4                Tfue           3671000070                123660
# ..                ...                  ...                   ...
# 995         LITkillah            122524635                 13560
# 996  빅헤드 (bighead033)            122523705                153000
# 997    마스카 (newmasca)            122452320                217410
# 998     AndyMilonakis            122311065                104745
# 999              Remx            122192850                 99180
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 0          222720            27716    3246298           1734810      93036735
# ...

# %%
# Filter data based on language (English only)
df_streamer_english = df_streamer[df_streamer['Language'] == 'English']
df_streamer_english
# Out:
#                Channel  Watch time(Minutes)  Stream time(minutes)  \
# 0                xQcOW           6196161750                215250
# 1             summit1g           6091677300                211845
# 3             ESL_CSGO           3970318140                517740
# 4                 Tfue           3671000070                123660
# 5            Asmongold           3668799075                 82260
# ..                 ...                  ...                   ...
# 990           KEEMSTAR            123365895                  3465
# 992         RelaxBeats            123273930                521430
# 993  LAGTVMaximusBlack            123125340                161535
# 994        Destructoid            122628630                103020
# 998      AndyMilonakis            122311065                104745
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 0          222720            27716    3246298           1734810      93036735
# ...

# %%
# Check to see if we have duplicates
len(df_streamer_english['Channel'].unique())
# Out:
# 485

# %%
# Sort data frame based on average viewers
df_streamer_english.sort_values(by = 'Average viewers', ascending = False)
# Out:
#              Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 81           dota2ti           1017577605                  6315        483530
# 41               LCS           1461310140                 31125        214124
# 5          Asmongold           3668799075                 82260        263720
# 52      RocketLeague           1322448480                 33540        206681
# 46               LCK           1351758525                 37140        171861
# ..               ...                  ...                   ...           ...
# 605    StreamerHouse            199501650                496545         12609
# 641         Speedrun            186800430                500010         16604
# 746       Monstercat            163589370                519675         14261
# 828  MarketTradersTV            148900110                499215          1357
# 992       RelaxBeats            123273930                521430          2830
#
# ...

# %%
# Sorting values by followers
df_filtered = df_streamer_english.sort_values(by = 'Followers', ascending = False)

# %%
# Reset Index and getting the top 50 channel on twitch
df_filtered = df_filtered.reset_index(drop = True)
df_top_50 = df_filtered.head(50)

# %%
# Writing to csv in data called top_50_channel.csv
df_top_50.to_csv("Data/top_50_channel.csv", index = False)

# %%
#
