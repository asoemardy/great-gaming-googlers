# %%
# Getting dependencies
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
import threading

# %%
# Pulling top 50 data from csv file in Data
df_top50 = pd.read_csv('Data/top_50_channel.csv')
df_top50.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0      Tfue           3671000070                123660        285644
# 1    shroud            888505170                 30240        471281
# 2      Myth           1479214575                134760        122552
# 3  pokimane            964334055                 56505        112160
# 4  summit1g           6091677300                211845        310998
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            29602    8938903           2068424      78998587       True
# 1            29612    7744066            833587      30621257       True
# 2             9396    6726893           1421811      37384058       True
# 3            16026    5367605           2085831      45579002       True
# 4            25610    5310163           1370184      89705964       True
#
#    Mature Language
# 0   False  English
# 1   False  English
# 2   False  English
# 3   False  English
# 4   False  English

# %%
# Setting up base API Calls
# Setting up the URL
url_channel = 'https://api.twitch.tv/helix/search/channels'
url_games = 'https://api.twitch.tv/helix/games'

# Setting up the headers
headers_channel = {
    'client-id': 'py6ylcmszc7x2mv3ssej6cxhe3qaj9',
    'Authorization': 'Bearer qa1qavdau81s0hm14dbnu8t5ty32h4',
}

headers_games = {
    'Authorization': 'Bearer qa1qavdau81s0hm14dbnu8t5ty32h4',
    'Client-Id': 'py6ylcmszc7x2mv3ssej6cxhe3qaj9',
}

# %%
game_id_list = []

# %%
for index, row in df_top50.iterrows():
    params_channel = (
    ('query', row['Channel']),
    )
    
    response = requests.get(url_channel, headers=headers_channel, params=params_channel).json()
    results = response['data']
    game_id_list.append(results[0]['game_id'])

# %%
for count in range(50):
    del game_id_list[0]

game_id_list
# Out:
# ['512710',
#  '516575',
#  '509658',
#  '509658',
#  '516575',
#  '509658',
#  '510218',
#  '21779',
#  '512710',
#  '18122',
#  '512710',
#  '32399',
#  '0',
#  '33214',
#  '21779',
#  '27471',
#  '33214',
#  '509658',
#  '33214',
#  '33214',
#  '498744',
#  '509658',
#  '498744',
#  '21779',
#  '32399',
#  '518204',
#  '512710',
#  '512710',
#  '459931',
#  '512710',
#  '518184',
#  '12839',
#  '510218',
#  '506342',
#  '510218',
#  '32399',
#  '488552',
#  '21779',
#  '459931',
#  '33214',
#  '313178',
#  '513143',
#  '509659',
#  '512710',
#  '510218',
#  '32399',
#  '12839',
#  '510218',
#  '21779',
#  '33214']

# %%
df_streamer_game = df_top50.copy()
df_streamer_game['Game ID'] = game_id_list
df_streamer_game.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0      Tfue           3671000070                123660        285644
# 1    shroud            888505170                 30240        471281
# 2      Myth           1479214575                134760        122552
# 3  pokimane            964334055                 56505        112160
# 4  summit1g           6091677300                211845        310998
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            29602    8938903           2068424      78998587       True
# 1            29612    7744066            833587      30621257       True
# 2             9396    6726893           1421811      37384058       True
# 3            16026    5367605           2085831      45579002       True
# 4            25610    5310163           1370184      89705964       True
#
#    Mature Language Game ID
# 0   False  English  512710
# 1   False  English  516575
# 2   False  English  509658
# 3   False  English  509658
# 4   False  English  516575

# %%
df_streamer_game = df_streamer_game[['Channel', 'Average viewers' , 'Followers', 'Game ID']]
df_streamer_game.head()
# Out:
#     Channel  Average viewers  Followers Game ID
# 0      Tfue            29602    8938903  512710
# 1    shroud            29612    7744066  516575
# 2      Myth             9396    6726893  509658
# 3  pokimane            16026    5367605  509658
# 4  summit1g            25610    5310163  516575

# %%
game_name = []

# %%
for index, row in df_streamer_game.iterrows():
    params_games = (
    ('id', row['Game ID']),
    )
    
    response = requests.get(url_games, headers=headers_games, params=params_games).json()
    results = response['data']
    
    try:
        game_name.append(results[0]['name'])
    
    except (KeyError, IndexError):
        game_name.append('NA')

# %%
game_name
# Out:
# ['Call Of Duty: Modern Warfare',
#  'VALORANT',
#  'Just Chatting',
#  'Just Chatting',
#  'VALORANT',
#  'Just Chatting',
#  'Among Us',
#  'League of Legends',
#  'Call Of Duty: Modern Warfare',
#  'World of Warcraft',
#  'Call Of Duty: Modern Warfare',
#  'Counter-Strike: Global Offensive',
#  'NA',
#  'Fortnite',
#  'League of Legends',
#  'Minecraft',
#  'Fortnite',
#  'Just Chatting',
#  'Fortnite',
#  'Fortnite',
#  'SCP: Secret Laboratory',
#  'Just Chatting',
#  'SCP: Secret Laboratory',
#  'League of Legends',
#  'Counter-Strike: Global Offensive',
#  'FIFA 21',
#  'Call Of Duty: Modern Warfare',
#  'Call Of Duty: Modern Warfare',
#  'Old School RuneScape',
#  'Call Of Duty: Modern Warfare',
#  'Phasmophobia',
#  'Heroes of Might and Magic III: The Restoration of Erathia',
#  'Among Us',
#  'HITMAN 2',
#  'Among Us',
#  'Counter-Strike: Global Offensive',
#  'Overwatch',
#  'League of Legends',
#  'Old School RuneScape',
#  'Fortnite',
#  'Disgaea 5: Alliance of Vengeance',
#  'Teamfight Tactics',
#  'ASMR',
#  'Call Of Duty: Modern Warfare',
#  'Among Us',
#  'Counter-Strike: Global Offensive',
#  'Heroes of Might and Magic III: The Restoration of Erathia',
#  'Among Us',
#  'League of Legends',
#  'Fortnite']

# %%
df_complete = df_streamer_game.copy()
df_complete['Game Name'] = game_name
df_complete
# Out:
#                    Channel  Average viewers  Followers Game ID  \
# 0                     Tfue            29602    8938903  512710
# 1                   shroud            29612    7744066  516575
# 2                     Myth             9396    6726893  509658
# 3                 pokimane            16026    5367605  509658
# 4                 summit1g            25610    5310163  516575
# 5             TimTheTatman            25664    5265659  509658
# 6                  dakotaz             7112    4520305  510218
# 7   Riot Games (riotgames)            20960    4487489   21779
# 8             DrDisrespect            23794    4450718  512710
# 9                   DrLupo             8311    4115083   18122
# 10               NICKMERCS            24181    4074287  512710
# 11                ESL_CSGO             7714    3944850   32399
# 12                SypherPK             6553    3611359       0
# 13                Fortnite            28584    3558217   33214
# 14               loltyler1            22381    3530767   21779
# 15                   xQcOW            27716    3246298   27471
# 16                   Fresh             9728    3135667   33214
# 17               Syndicate             4281    3000509  509658
# 18                Mongraal            18180    2951980   33214
# 19                   Bugha            12982    2942212   33214
# 20              sodapoppin            19659    2786162  498744
# 21                   LIRIK            21739    2666382  509658
# 22                imaqtpie             3478    2652018  498744
# 23              Nightblue3             7234    2641880   21779
# 24                 Anomaly            12377    2607076   32399
# 25             Castro_1021            17779    2411995  518204
